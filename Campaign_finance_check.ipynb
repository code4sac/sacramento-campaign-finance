# %% [markdown]
# # Checking the aggregated data against its sources

# %% [markdown]
# ## Agreggating the source JSON files into a single dataframe and grouping based on the column filerName

# %%
import os
import pandas as pd


# Function to read all JSON files from a folder into a single DataFrame
def read_jsons_from_folder(folder_path):
    all_files = [f for f in os.listdir(folder_path) if f.endswith('.json')]
    df_list = []
    
    for file in all_files:
        file_path = os.path.join(folder_path, file)
        df = pd.read_json(file_path)
        df_list.append(df)
    
    # Concatenate all DataFrames into a single DataFrame
    combined_df = pd.concat(df_list, ignore_index=True)
    return combined_df
folder_path = 'data/'
combined_df = read_jsons_from_folder(folder_path)

# %%
# List of names to filter 'filerName' column by
names_to_filter = ['Maple', 'Steinberg', 'Guerra',
                   'Talamantes', 'Valenzuela', 'Kaplan', 
                   'Vang', 'Hume', 'Kennedy', 'Sterna', 
                   'Desmond', 'Jennings', 'Loloee', 'Frost']

# Create a function to check if any substring in a list appears in a string
def contains_any_substring(string, substrings):
    return any(sub.lower() in string.lower() for sub in substrings)

# Filter the DataFrame to include only rows where 'filerName' contains any of the specified names
filtered_df_partial_match = combined_df[combined_df['filerName'].apply(lambda x: contains_any_substring(x, names_to_filter))]

# Group by 'filerName' and aggregate the 'amount'
aggregated_by_filer_partial_match = filtered_df_partial_match.groupby('filerName').agg({'amount': 'sum'}).reset_index()

# Display the aggregated DataFrame
# aggregated_by_filer_partial_match

# %% [markdown]
# ## Comparing totals to the aggregated JSON data object flattened into a dataframe reveal discrepencies for every campaign total

# %%
aggregated_totals = pd.read_json('src/lib/data.json')
# Flatten the 'data' column into its own DataFrame
data_flattened_df = pd.json_normalize(aggregated_totals['data'])

# Explode the 'committees' and 'contributors' columns to unpack the nested lists
exploded_committees = data_flattened_df.explode('committees')
exploded_contributors = data_flattened_df.explode('contributors')

# Flatten the dictionaries in the exploded 'committees' and 'contributors' columns
flattened_committees = pd.json_normalize(exploded_committees['committees'])
flattened_contributors = pd.json_normalize(exploded_contributors['contributors'])

# Merge the flattened DataFrames back with the original columns (excluding the exploded ones)
final_committees_df = pd.concat([exploded_committees.drop('committees', axis=1).reset_index(drop=True), flattened_committees], axis=1)
final_contributors_df = pd.concat([exploded_contributors.drop('contributors', axis=1).reset_index(drop=True), flattened_contributors], axis=1)

# Aggregate contributions by 'filerName'
aggregated_contributions = final_contributors_df.groupby([ 'filerName']).agg({'amount': 'sum'}).reset_index()

# Display the aggregated DataFrames
# aggregated_contributions

# %%
# from individual json files
# aggregated_by_filer_partial_match
# from aggregated data.json
# aggregated_contributions
aggregated_by_filer_partial_match.merge(aggregated_contributions, on="filerName", how="left", suffixes=["_individual_files", "_aggregated"])
# Out:
#                                             filerName  \
# 0                   Caity Maple for City Council 2022
# 1                   Caity Maple for City Council 2026
# 2                   Eric Guerra for City Council 2015
# 3                   Eric Guerra for City Council 2016
# 4                   Eric Guerra for City Council 2020
# 5                   Eric Guerra for City Council 2024
# 6   For A Better Sacramento, a Committee to Recall...
# 7                            Hume for Supervisor 2022
# 8             Karina Talamantes for City Council 2022
# 9             Karina Talamantes for City Council 2026
# 10            Karina Talamantes for SCOE Trustee 2018
# 11            Karina Talamantes for SCOE Trustee 2022
# 12  Katie Valenzuela for Sacramento City Council 2020
# 13  Katie Valenzuela for Sacramento City Council 2024
# 14                  Lisa Kaplan for City Council 2022
# 15            Lisa Kaplan, Natomas School Board, 2018
# 16            Lisa Kaplan, Natomas School Board, 2022
# 17                     Mai Vang for City Council 2020
# 18                     Mai Vang for City Council 2024
# 19                     Mai Vang for School Board 2016
# 20  Mayor Darrell Steinberg Committee for Sacramen...
# 21                Patrick Kennedy for Supervisor 2018
# 22                Patrick Kennedy for Supervisor 2022
# 23                   Rich Desmond for Supervisor 2020
# 24                   Rich Desmond for Supervisor 2024
# 25                Rick Jennings for City Council 2014
# 26                Rick Jennings for City Council 2018
# 27                Rick Jennings for City Council 2022
# 28  Sacramentans Against the Recall of Councilmemb...
# 29  Sacramentans for Jobs and Economic Growth supp...
# 30  Sacramentans for Public Libraries 2016 - Yes o...
# 31  Sacramentans for Public Libraries 2016, City C...
# 32  Sacramento Working Families supporting Valenzu...
# 33                  Sean Loloee for City Council 2020
# 34                  Sean Loloee for City Council 2024
# 35                Steinberg for Sacramento Mayor 2016
# 36                Steinberg for Sacramento Mayor 2020
# 37                Steinberg for Sacramento Mayor 2024
# 38                      Sue Frost for Supervisor 2016
# 39                      Sue Frost for Supervisor 2020
# 40                      Sue Frost for Supervisor 2024
# 41  The Coalition for Jobs and Economic Growth sup...
# 42  Yes on Measure L Sac Kids 2022 Vang Ballot Mea...
# 43  Yes on Measure U - Mayor Darrell Steinberg Com...
#
#     amount_individual_files  amount_aggregated
# 0                 189032.32          189032.32
# 1                  10271.00           10271.00
# 2                 214918.62          214918.62
# 3                 115796.62          115796.62
# 4                 190794.00          190794.00
# 5                  72191.03           72191.03
# 6                  33312.85                NaN
# 7                 737219.93          737219.93
# 8                 310656.30          310656.30
# 9                   2000.00                NaN
# 10                 35290.54                NaN
# 11                 34750.00                NaN
# 12                 68424.74           68424.74
# 13                 80159.00           80159.00
# 14                315329.40          315329.40
# 15                 42600.54                NaN
# 16                 19516.90                NaN
# 17                192053.27          192053.27
# 18                 87248.35           87248.35
# 19                 60012.41           60012.41
# 20                811570.01                NaN
# 21                 85670.00           85670.00
# 22                143967.70          143967.70
# 23                399240.56          435589.56
# 24                105967.00           69618.00
# 25                155946.77          155946.77
# 26                168195.47          168195.47
# 27                 61300.00           61300.00
# 28                 33000.00                NaN
# 29                 82670.00                NaN
# 30                 76673.60                NaN
# 31                 37500.00                NaN
# 32                 61668.33                NaN
# 33                125528.81          125528.81
# 34                  4905.00            4905.00
# 35               2294038.81         2294038.81
# 36                455788.93          455788.93
# 37                410656.71          410656.71
# 38                151059.03          250453.59
# 39                229870.40          141825.84
# 40                 20899.00            9549.00
# 41                 47819.69                NaN
# 42                279089.19                NaN
# 43                477696.51                NaN
